# %% [markdown]
# <a href="https://colab.research.google.com/github/ankitadas25/MachineLearing/blob/main/02_May_Lab02_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#%matplotlib inline

# %% [markdown]
# # Read the data set of "Marketing Analysis" in data.

# %%
df_market=pd.read_csv('Marketing_Analysis.csv')
print(df_market)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-a9d7c5f47934> in <cell line: 1>()
# ----> 1 df_market=pd.read_csv('Marketing_Analysis.csv')
#       2 print(df_market)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df_market.head(10)
# Out:
#       banking marketing Unnamed: 1                    Unnamed: 2 Unnamed: 3  \
# 0  customer id and age.        NaN  Customer salary and balance.        NaN
# 1            customerid        age                        salary    balance
# 2                     1         58                        100000       2143
# 3                     2         44                         60000         29
# 4                     3         33                        120000          2
# 5                     4         47                         20000       1506
# 6                     5         33                             0          1
# 7                     6         35                        100000        231
# 8                     7         28                        100000        447
# 9                     8         42                        120000          2
#
#                                           Unnamed: 4              Unnamed: 5  \
# ...

# %%
df_market = pd.read_csv("Marketing_Analysis.csv",skiprows = 2)

# %%
df_market
# Out:
#        customerid   age  salary  balance   marital                  jobedu  \
# 0               1  58.0  100000     2143   married     management,tertiary
# 1               2  44.0   60000       29    single    technician,secondary
# 2               3  33.0  120000        2   married  entrepreneur,secondary
# 3               4  47.0   20000     1506   married     blue-collar,unknown
# 4               5  33.0       0        1    single         unknown,unknown
# 5               6  35.0  100000      231   married     management,tertiary
# 6               7  28.0  100000      447    single     management,tertiary
# 7               8  42.0  120000        2  divorced   entrepreneur,tertiary
# 8               9  58.0   55000      121   married         retired,primary
# 9              10  43.0   60000      593    single    technician,secondary
# 10             11  41.0   50000      270  divorced        admin.,secondary
# ...

# %%
# Drop the customer id as it is of no use.
# drop is used to drop an column
df_market.drop('customerid', axis = 1, inplace = True)

# %%
df_market
# Out:
#         age  salary  balance   marital                  jobedu targeted  \
# 0      58.0  100000     2143   married     management,tertiary      yes
# 1      44.0   60000       29    single    technician,secondary      yes
# 2      33.0  120000        2   married  entrepreneur,secondary      yes
# 3      47.0   20000     1506   married     blue-collar,unknown       no
# 4      33.0       0        1    single         unknown,unknown       no
# 5      35.0  100000      231   married     management,tertiary      yes
# 6      28.0  100000      447    single     management,tertiary       no
# 7      42.0  120000        2  divorced   entrepreneur,tertiary       no
# 8      58.0   55000      121   married         retired,primary      yes
# 9      43.0   60000      593    single    technician,secondary      yes
# 10     41.0   50000      270  divorced        admin.,secondary      yes
# 11     29.0   50000      390    single        admin.,secondary      yes
# ...

# %% [markdown]
# #Extract job  & Education in newly from "jobedu" column.

# %%
df_market['job']= df_market["jobedu"].apply(lambda x: x.split(",")[0])
df_market['education']= df_market["jobedu"].apply(lambda x: x.split(",")[1])

# %%
df_market.head(10)
# Out:
#     age  salary  balance   marital                  jobedu targeted default  \
# 0  58.0  100000     2143   married     management,tertiary      yes      no
# 1  44.0   60000       29    single    technician,secondary      yes      no
# 2  33.0  120000        2   married  entrepreneur,secondary      yes      no
# 3  47.0   20000     1506   married     blue-collar,unknown       no      no
# 4  33.0       0        1    single         unknown,unknown       no      no
# 5  35.0  100000      231   married     management,tertiary      yes      no
# 6  28.0  100000      447    single     management,tertiary       no      no
# 7  42.0  120000        2  divorced   entrepreneur,tertiary       no     yes
# 8  58.0   55000      121   married         retired,primary      yes      no
# 9  43.0   60000      593    single    technician,secondary      yes      no
#
#   housing loan  contact  day      month duration  campaign  pdays  previous  \
# ...

# %% [markdown]
# # Drop the "jobedu" column from the dataframe.

# %%
df_market.drop('jobedu', axis = 1, inplace = True)

# %%
df_market.head(10)
# Out:
#     age  salary  balance   marital targeted default housing loan  contact  \
# 0  58.0  100000     2143   married      yes      no     yes   no  unknown
# 1  44.0   60000       29    single      yes      no     yes   no  unknown
# 2  33.0  120000        2   married      yes      no     yes  yes  unknown
# 3  47.0   20000     1506   married       no      no     yes   no  unknown
# 4  33.0       0        1    single       no      no      no   no  unknown
# 5  35.0  100000      231   married      yes      no     yes   no  unknown
# 6  28.0  100000      447    single       no      no     yes  yes  unknown
# 7  42.0  120000        2  divorced       no     yes     yes   no  unknown
# 8  58.0   55000      121   married      yes      no     yes   no  unknown
# 9  43.0   60000      593    single      yes      no     yes   no  unknown
#
#    day      month duration  campaign  pdays  previous poutcome response  \
# 0    5  may, 2017  261 sec         1     -1         0  unknown       no
# ...

# %% [markdown]
# # Checking the missing values

# %%
df_market.isnull().sum()
# Out:
# age          20
# salary        0
# balance       0
# marital       0
# targeted      0
# default       0
# housing       0
# loan          0
# contact       0
# day           0
# month        50
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# response     30
# job           0
# education     0
# dtype: int64

# %% [markdown]
# #Drop the missing Values

# %%
# Dropping the records with age missing in data dataframe.
df_market = df_market[~df_market.age.isnull()].copy()

# Checking the missing values in the dataset.
df_market.isnull().sum()
# Out:
# age           0
# salary        0
# balance       0
# marital       0
# targeted      0
# default       0
# housing       0
# loan          0
# contact       0
# day           0
# month        50
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# response     30
# job           0
# education     0
# dtype: int64

# %% [markdown]
# #Impute values to the missing values

# %%
# Find the mode of month in data
month_mode = df_market.month.mode()[0]
print(month_mode)
# Fill the missing values with mode value of month in data.
df_market.month.fillna(month_mode, inplace = True)

# Let's see the null values in the month column.
df_market.month.isnull().sum()
# Out:
# may, 2017
# 0

# %%
#drop the records with response missing in data.
df_market = df_market[~df_market.response.isnull()].copy()
# Calculate the missing values in each column of data frame
df_market.isnull().sum()
# Out:
# age          0
# salary       0
# balance      0
# marital      0
# targeted     0
# default      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# response     0
# job          0
# education    0
# dtype: int64

# %% [markdown]
# #Handling Outliers

# %% [markdown]
# **Univariate outliers**: Univariate outliers are the data points whose values lie beyond the range of expected values based on one variable.
#
# **Multivariate outliers:** While plotting data, some values of one variable may not lie beyond the expected range, but when you plot the data with some other variable, these values may lie far from the expected value.

# %% [markdown]
# Categorical Unordered Univariate Analysis

# %%
# Let's calculate the percentage of each job status category.
df_market.job.value_counts()

#plot the bar graph of percentage job categories
df_market.job.value_counts().plot.bar()
plt.show()

# %% [markdown]
# Categorical Ordered Univariate Analysis:

# %%
#calculate the percentage of each education category.
df_market.education.value_counts(normalize=True)

#plot the pie chart of education categories
df_market.education.value_counts(normalize=True).plot.pie()
plt.show()

# %%
df_market.salary.describe()
# Out:
# count     45161.000000
# mean      57004.849317
# std       32087.698810
# min           0.000000
# 25%       20000.000000
# 50%       60000.000000
# 75%       70000.000000
# max      120000.000000
# Name: salary, dtype: float64

# %% [markdown]
# Bivariate Analysis - *Numeric*-Numeric Analysis:

# %%
#plot the scatter plot of balance and salary variable in data
plt.scatter(df_market.salary,df_market.balance)
plt.show()

#plot the scatter plot of balance and age variable in data
df_market.plot.scatter(x="age",y="balance")
plt.show()

# %%
#plot the pair plot of salary, balance and age in data dataframe.
sns.pairplot(data = df_market, vars=['salary','balance','age'])
plt.show()

# %% [markdown]
# Correlation Matrix

# %%
# Creating a matrix using age, salry, balance as rows and columns
df_market[['age','salary','balance']].corr()

#plot the correlation matrix of salary, balance and age in data dataframe.
sns.heatmap(df_market[['age','salary','balance']].corr(), annot=True, cmap = 'Reds')
plt.show()

# %% [markdown]
# Bivariate Analysis - Numeric - Categorical Analysis

# %%
#groupby the response to find the mean of the salary with response no & yes separately.
df_market.groupby('response')['salary'].mean()
# Out:
# response
# no     56769
# yes    58780
# Name: salary, dtype: int64

# %%
df_market.groupby('response')['salary'].median()
# Out:
# response
# no     60000
# yes    60000
# Name: salary, dtype: int64

# %%
sns.boxplot(x=df_market.response,y= df_market.salary)
plt.show()

# %% [markdown]
# Categorical — Categorical Analysis

# %%
df_market['response_rate'] = np.where(df_market.response=='yes',1,0)
df_market.response_rate.value_counts()
# Out:
# 0    39876
# 1     5285
# Name: response_rate, dtype: int64

# %%
#plot the bar graph of marital status with average value of response_rate
df_market.groupby('marital')['response_rate'].mean().plot.bar()
plt.show()

# %% [markdown]
# Multivariate Analysis

# %%
result = pd.pivot_table(data=df_market, index='education', columns='marital',values='response_rate')
print(result)
# Out:
# marital    divorced   married    single
# education
# primary    0.138852  0.075601  0.106808
# secondary  0.103559  0.094650  0.129271
# tertiary   0.137415  0.129835  0.183737
# unknown    0.142012  0.122519  0.162879

# %%
#create heat map of education vs marital vs response_rate
sns.heatmap(result, annot=True, cmap = 'RdYlGn', center=0.117)
plt.show()

# %% [markdown]
# # Conclusions

# %% [markdown]
# Exploratory Data Analysis (EDA) helps us to look beyond the data. The more we explore the data, the more the insights we draw from it. As a data analyst, almost 80% of our time will be spent understanding data and solving various business problems through EDA
